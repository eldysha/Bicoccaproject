# %%
import pandas as pd
import numpy as np
# disable chained assignments
pd.options.mode.chained_assignment = None 
# dataset import
df_store = pd.read_csv('https://raw.githubusercontent.com/gdv/foundationsCS-2018/master/ex-data/project/googleplaystore.csv')
df_reviews = pd.read_csv('https://raw.githubusercontent.com/gdv/foundationsCS-2018/master/ex-data/project/googleplaystore_user_reviews.csv')
df_store
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring       ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 20                           Logo Maker - Small Business       ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit       ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 27                                 Animated Photo Editor       ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing       ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10811                                        FR Plus 1.6    AUTO_AND_VEHICLES
# 10812                                      Fr Agnel Pune               FAMILY
# 10813                                     DICT.fr Mobile             BUSINESS
# 10814                               FR: My Secret Pets!                FAMILY
# 10815                          Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE
# 10816                                 FieldBi FR Offline             BUSINESS
# 10817                               HTC Sense Input - FR                TOOLS
# 10818                               Gold Quote - Gold.fr              FINANCE
# 10819                                          Fanfic-FR  BOOKS_AND_REFERENCE
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10821                                            Poop FR               FAMILY
# 10822                                          PLMGSS FR         PRODUCTIVITY
# 10823                                       List iptv FR        VIDEO_PLAYERS
# 10824                                          Cardio-FR              MEDICAL
# 10825                                 Naruto & Boruto FR               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10827                                 Fr Agnel Ambarnath               FAMILY
# 10828                            Manga-FR - Anime Vostfr               COMICS
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                                  News Minecraft.fr   NEWS_AND_MAGAZINES
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                           FR Tides              WEATHER
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# 5         4.4     167                5.6M      50,000+  Free     0
# 6         3.8     178                 19M      50,000+  Free     0
# 7         4.1   36815                 29M   1,000,000+  Free     0
# 8         4.4   13791                 33M   1,000,000+  Free     0
# 9         4.7     121                3.1M      10,000+  Free     0
# 10        4.4   13880                 28M   1,000,000+  Free     0
# 11        4.4    8788                 12M   1,000,000+  Free     0
# 12        4.2   44829                 20M  10,000,000+  Free     0
# 13        4.6    4326                 21M     100,000+  Free     0
# 14        4.4    1518                 37M     100,000+  Free     0
# 15        3.2      55                2.7M       5,000+  Free     0
# 16        4.7    3632                5.5M     500,000+  Free     0
# 17        4.5      27                 17M      10,000+  Free     0
# 18        4.3  194216                 39M   5,000,000+  Free     0
# 19        4.6  224399                 31M  10,000,000+  Free     0
# 20        4.0     450                 14M     100,000+  Free     0
# 21        4.1     654                 12M     100,000+  Free     0
# 22        4.7    7699                4.2M     500,000+  Free     0
# 23        NaN      61                7.0M     100,000+  Free     0
# 24        4.7     118                 23M      50,000+  Free     0
# 25        4.8     192                6.0M      10,000+  Free     0
# 26        4.7   20260                 25M     500,000+  Free     0
# 27        4.1     203                6.1M     100,000+  Free     0
# 28        3.9     136                4.6M      10,000+  Free     0
# 29        4.1     223                4.2M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10811     NaN       4                3.9M         100+  Free     0
# 10812     4.1      80                 13M       1,000+  Free     0
# 10813     NaN      20                2.7M      10,000+  Free     0
# 10814     4.0     785                 31M      50,000+  Free     0
# 10815     4.2    5775                4.9M     500,000+  Free     0
# 10816     NaN       2                6.8M         100+  Free     0
# 10817     4.0     885                8.0M     100,000+  Free     0
# 10818     NaN      96                1.5M      10,000+  Free     0
# 10819     3.3      52                3.6M       5,000+  Free     0
# 10820     5.0      22                8.6M       1,000+  Free     0
# 10821     NaN       6                2.5M          50+  Free     0
# 10822     NaN       0                3.1M          10+  Free     0
# 10823     NaN       1                2.9M         100+  Free     0
# 10824     NaN      67                 82M      10,000+  Free     0
# 10825     NaN       7                7.7M         100+  Free     0
# 10826     4.0   88486  Varies with device   5,000,000+  Free     0
# 10827     4.2     117                 13M       5,000+  Free     0
# 10828     3.4     291                 13M      10,000+  Free     0
# 10829     4.6     603                7.4M      10,000+  Free     0
# 10830     3.8     881                2.3M     100,000+  Free     0
# 10831     NaN      38                9.8M       5,000+  Free     0
# 10832     3.8    1195                582k     100,000+  Free     0
# 10833     4.8      44                619k       1,000+  Free     0
# 10834     4.0       7                2.6M         500+  Free     0
# 10835     NaN       0                9.6M          10+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                           Genres        Last Updated  \
# 0           Everyone                     Art & Design     January 7, 2018
# 1           Everyone        Art & Design;Pretend Play    January 15, 2018
# 2           Everyone                     Art & Design      August 1, 2018
# 3               Teen                     Art & Design        June 8, 2018
# 4           Everyone          Art & Design;Creativity       June 20, 2018
# 5           Everyone                     Art & Design      March 26, 2017
# 6           Everyone                     Art & Design      April 26, 2018
# 7           Everyone                     Art & Design       June 14, 2018
# 8           Everyone                     Art & Design  September 20, 2017
# 9           Everyone          Art & Design;Creativity        July 3, 2018
# 10          Everyone                     Art & Design    October 27, 2017
# 11          Everyone                     Art & Design       July 31, 2018
# 12              Teen                     Art & Design       April 2, 2018
# 13          Everyone                     Art & Design       June 26, 2018
# 14          Everyone                     Art & Design      August 3, 2018
# 15          Everyone                     Art & Design        June 6, 2018
# 16          Everyone                     Art & Design       July 31, 2018
# 17          Everyone                     Art & Design    November 7, 2017
# 18          Everyone                     Art & Design      August 3, 2018
# 19          Everyone                     Art & Design       July 30, 2018
# 20          Everyone                     Art & Design      April 20, 2018
# 21          Everyone                     Art & Design      March 20, 2018
# 22      Everyone 10+                     Art & Design       July 12, 2018
# 23          Everyone  Art & Design;Action & Adventure       March 7, 2018
# 24          Everyone                     Art & Design        July 7, 2018
# 25          Everyone                     Art & Design      April 25, 2018
# 26          Everyone          Art & Design;Creativity    October 11, 2017
# 27          Everyone                     Art & Design      March 21, 2018
# 28          Everyone                     Art & Design       July 12, 2018
# 29          Everyone                     Art & Design     August 22, 2017
# ...              ...                              ...                 ...
# 10811       Everyone                  Auto & Vehicles       July 24, 2018
# 10812       Everyone                        Education       June 13, 2018
# 10813       Everyone                         Business       July 17, 2018
# 10814           Teen                    Entertainment        June 3, 2015
# 10815       Everyone                Books & Reference       July 19, 2018
# 10816       Everyone                         Business      August 6, 2018
# 10817       Everyone                            Tools    October 30, 2015
# 10818       Everyone                          Finance        May 19, 2016
# 10819           Teen                Books & Reference      August 5, 2017
# 10820           Teen                        Education       June 27, 2018
# 10821       Everyone                    Entertainment        May 29, 2018
# 10822       Everyone                     Productivity    December 1, 2017
# 10823       Everyone          Video Players & Editors      April 22, 2018
# 10824       Everyone                          Medical       July 31, 2018
# 10825           Teen                           Social    February 2, 2018
# 10826     Mature 17+                           Social      March 23, 2018
# 10827       Everyone                        Education       June 13, 2018
# 10828       Everyone                           Comics        May 15, 2017
# 10829       Everyone                Books & Reference       June 19, 2016
# 10830       Everyone                 News & Magazines    January 20, 2014
# 10831       Everyone                Maps & Navigation       June 13, 2018
# 10832       Everyone                          Weather   February 16, 2014
# 10833       Everyone                Books & Reference      March 23, 2014
# 10834       Everyone                        Education       June 18, 2017
# 10835       Everyone                         Business  September 29, 2016
# 10836       Everyone                        Education       July 25, 2017
# 10837       Everyone                        Education        July 6, 2018
# 10838       Everyone                          Medical    January 20, 2017
# 10839     Mature 17+                Books & Reference    January 19, 2015
# 10840       Everyone                        Lifestyle       July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# 5                     1.0          2.3 and up
# 6                     1.1        4.0.3 and up
# 7                6.1.61.1          4.2 and up
# 8                   2.9.2          3.0 and up
# 9                     2.8        4.0.3 and up
# 10                  1.0.4          4.1 and up
# 11                 1.0.15          4.0 and up
# 12                    3.8          4.1 and up
# 13                  1.0.4          4.4 and up
# 14                  1.2.3          2.3 and up
# 15                    NaN          4.2 and up
# 16                    3.1          4.1 and up
# 17                    1.0          2.3 and up
# 18                  2.2.5        4.0.3 and up
# 19                  5.5.4          4.1 and up
# 20                    4.0          4.1 and up
# 21                    1.1        4.0.3 and up
# 22                2.2.6.2        4.0.3 and up
# 23                  1.0.0          4.1 and up
# 24                  1.1.3          4.1 and up
# 25                    1.5          3.0 and up
# 26                  1.0.8        4.0.3 and up
# 27                   1.03        4.0.3 and up
# 28                    6.0          2.3 and up
# 29                    1.0          2.3 and up
# ...                   ...                 ...
# 10811               1.3.6         4.4W and up
# 10812              2.0.20        4.0.3 and up
# 10813              2.1.10          4.1 and up
# 10814               1.3.1          3.0 and up
# 10815             7.0.4.6          4.2 and up
# 10816               2.1.8          4.1 and up
# 10817          1.0.612928          5.0 and up
# 10818                 2.3          2.2 and up
# 10819               0.3.4          4.1 and up
# 10820               3.8.0          4.1 and up
# 10821                 1.0        4.0.3 and up
# 10822                   1          4.4 and up
# 10823                 1.0        4.0.3 and up
# 10824               2.2.2          4.4 and up
# 10825                 1.0          4.0 and up
# 10826  Varies with device  Varies with device
# 10827              2.0.20        4.0.3 and up
# 10828               2.0.1          4.0 and up
# 10829                2.96          4.1 and up
# 10830                 1.5          1.6 and up
# 10831           2.0.148.0          4.0 and up
# 10832                 6.0          2.1 and up
# 10833                 0.8          2.2 and up
# 10834               1.0.0          4.1 and up
# 10835               1.1.5          4.0 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %% [markdown]
# #    1.Convert the app sizes to a number

# %%
#remove invalid record
df_store=df_store.drop(df_store.index[10472])
df_store= df_store.reset_index(drop=True)

# %%
# convert M and k size
i=0
for n in df_store["Size"]:
    if str(df_store["Size"][i]).endswith("M"):
        df_store["Size"][i]=df_store["Size"][i][:-1]
        df_store["Size"][i]=float(df_store["Size"][i]) 
        df_store["Size"][i]=df_store["Size"][i]*10**6
    if str(df_store["Size"][i]).endswith("k"):
        df_store["Size"][i]=df_store["Size"][i][:-1]
        df_store["Size"][i]=float(df_store["Size"][i]) 
        df_store["Size"][i]=df_store["Size"][i]*10**3
    i=i+1
df_store.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size     Installs  Type Price Content Rating  \
# 0     159  1.9e+07      10,000+  Free     0       Everyone
# 1     967  1.4e+07     500,000+  Free     0       Everyone
# 2   87510  8.7e+06   5,000,000+  Free     0       Everyone
# 3  215644  2.5e+07  50,000,000+  Free     0           Teen
# 4     967  2.8e+06     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# #    2.Convert the number of installs to a number

# %%
# remove unwanted characters and transform values into number
i=0
for k in df_store["Installs"]:
    df_store["Installs"][i]=df_store["Installs"][i].replace(",","")
    df_store["Installs"][i]=df_store["Installs"][i].replace("+","")
    df_store["Installs"][i]=int(df_store["Installs"][i])
    i=i+1
df_store.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size  Installs  Type Price Content Rating  \
# 0     159  1.9e+07     10000  Free     0       Everyone
# 1     967  1.4e+07    500000  Free     0       Everyone
# 2   87510  8.7e+06   5000000  Free     0       Everyone
# 3  215644  2.5e+07  50000000  Free     0           Teen
# 4     967  2.8e+06    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# # 3.Transform “Varies with device” into a missing value

# %%
df_store=df_store.replace('Varies with device',np.nan)
df_store.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size  Installs  Type Price Content Rating  \
# 0     159  19000000.0     10000  Free     0       Everyone
# 1     967  14000000.0    500000  Free     0       Everyone
# 2   87510   8700000.0   5000000  Free     0       Everyone
# 3  215644  25000000.0  50000000  Free     0           Teen
# 4     967   2800000.0    100000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up
# 3               Art & Design      June 8, 2018         NaN    4.2 and up
# 4    Art & Design;Creativity     June 20, 2018         1.1    4.4 and up

# %% [markdown]
# # 4.Convert Current Ver and Android Ver into a dotted number (e.g. 4.0.3 or 4.2)

# %%
import re
#define a function to remove all character except for numbers and point character
def convert_number(var):
    try:
        return re.sub("[^0-9.]","",var)
               
    except:
        return np.nan

# %%
# apply previous function
df_store["Current Ver"]=df_store.apply(lambda x:convert_number(x["Current Ver"]),axis=1)
df_store["Android Ver"]=df_store.apply(lambda x:convert_number(x["Android Ver"]),axis=1)
df_store.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size  Installs  Type Price Content Rating  \
# 0     159  19000000.0     10000  Free     0       Everyone
# 1     967  14000000.0    500000  Free     0       Everyone
# 2   87510   8700000.0   5000000  Free     0       Everyone
# 3  215644  25000000.0  50000000  Free     0           Teen
# 4     967   2800000.0    100000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver Android Ver
# 0               Art & Design   January 7, 2018       1.0.0       4.0.3
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0       4.0.3
# 2               Art & Design    August 1, 2018       1.2.4       4.0.3
# 3               Art & Design      June 8, 2018         NaN         4.2
# 4    Art & Design;Creativity     June 20, 2018         1.1         4.4

# %% [markdown]
# # 5. Remove the duplicates

# %%
# Keep only first value for the duplicates records recognized through name and size
df_store = df_store.drop_duplicates(subset=['App','Size'], keep='first', inplace=False)
df_store= df_store.reset_index(drop=True)
df_store
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                            Paper flowers instructions       ART_AND_DESIGN
# 6               Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                      Infinite Painter       ART_AND_DESIGN
# 8                                  Garden Coloring Book       ART_AND_DESIGN
# 9                         Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                              Text on Photo - Fonteee       ART_AND_DESIGN
# 11              Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                       Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 13                                Mandala Coloring Book       ART_AND_DESIGN
# 14      3D Color Pixel by Number - Sandbox Art Coloring       ART_AND_DESIGN
# 15                      Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 16         Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 17                             350 Diy Room Decor Ideas       ART_AND_DESIGN
# 18                        FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                         ibis Paint X       ART_AND_DESIGN
# 20                          Logo Maker - Small Business       ART_AND_DESIGN
# 21            Boys Photo Editor - Six Pack & Men's Suit       ART_AND_DESIGN
# 22              Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 23                               Mcqueen Coloring pages       ART_AND_DESIGN
# 24                          HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                           Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                        Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 27                                Animated Photo Editor       ART_AND_DESIGN
# 28                                Pencil Sketch Drawing       ART_AND_DESIGN
# 29                      Easy Realistic Drawing Tutorial       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9648                                        FR Plus 1.6    AUTO_AND_VEHICLES
# 9649                                      Fr Agnel Pune               FAMILY
# 9650                                     DICT.fr Mobile             BUSINESS
# 9651                               FR: My Secret Pets!                FAMILY
# 9652                          Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE
# 9653                                 FieldBi FR Offline             BUSINESS
# 9654                               HTC Sense Input - FR                TOOLS
# 9655                               Gold Quote - Gold.fr              FINANCE
# 9656                                          Fanfic-FR  BOOKS_AND_REFERENCE
# 9657                                    Fr. Daoud Lamei               FAMILY
# 9658                                            Poop FR               FAMILY
# 9659                                          PLMGSS FR         PRODUCTIVITY
# 9660                                       List iptv FR        VIDEO_PLAYERS
# 9661                                          Cardio-FR              MEDICAL
# 9662                                 Naruto & Boruto FR               SOCIAL
# 9663          Frim: get new friends on local chat rooms               SOCIAL
# 9664                                 Fr Agnel Ambarnath               FAMILY
# 9665                            Manga-FR - Anime Vostfr               COMICS
# 9666                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 9667                                  News Minecraft.fr   NEWS_AND_MAGAZINES
# 9668                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 9669                                           FR Tides              WEATHER
# 9670                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 9671                                      FR Calculator               FAMILY
# 9672                                           FR Forms             BUSINESS
# 9673                                   Sya9a Maroc - FR               FAMILY
# 9674                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9675                             Parkinson Exercices FR              MEDICAL
# 9676                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9677      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating Reviews        Size  Installs  Type Price Content Rating  \
# 0        4.1     159  19000000.0     10000  Free     0       Everyone
# 1        3.9     967  14000000.0    500000  Free     0       Everyone
# 2        4.7   87510   8700000.0   5000000  Free     0       Everyone
# 3        4.5  215644  25000000.0  50000000  Free     0           Teen
# 4        4.3     967   2800000.0    100000  Free     0       Everyone
# 5        4.4     167   5600000.0     50000  Free     0       Everyone
# 6        3.8     178  19000000.0     50000  Free     0       Everyone
# 7        4.1   36815  29000000.0   1000000  Free     0       Everyone
# 8        4.4   13791  33000000.0   1000000  Free     0       Everyone
# 9        4.7     121   3100000.0     10000  Free     0       Everyone
# 10       4.4   13880  28000000.0   1000000  Free     0       Everyone
# 11       4.4    8788  12000000.0   1000000  Free     0       Everyone
# 12       4.2   44829  20000000.0  10000000  Free     0           Teen
# 13       4.6    4326  21000000.0    100000  Free     0       Everyone
# 14       4.4    1518  37000000.0    100000  Free     0       Everyone
# 15       3.2      55   2700000.0      5000  Free     0       Everyone
# 16       4.7    3632   5500000.0    500000  Free     0       Everyone
# 17       4.5      27  17000000.0     10000  Free     0       Everyone
# 18       4.3  194216  39000000.0   5000000  Free     0       Everyone
# 19       4.6  224399  31000000.0  10000000  Free     0       Everyone
# 20       4.0     450  14000000.0    100000  Free     0       Everyone
# 21       4.1     654  12000000.0    100000  Free     0       Everyone
# 22       4.7    7699   4200000.0    500000  Free     0   Everyone 10+
# 23       NaN      61   7000000.0    100000  Free     0       Everyone
# 24       4.7     118  23000000.0     50000  Free     0       Everyone
# 25       4.8     192   6000000.0     10000  Free     0       Everyone
# 26       4.7   20260  25000000.0    500000  Free     0       Everyone
# 27       4.1     203   6100000.0    100000  Free     0       Everyone
# 28       3.9     136   4600000.0     10000  Free     0       Everyone
# 29       4.1     223   4200000.0    100000  Free     0       Everyone
# ...      ...     ...         ...       ...   ...   ...            ...
# 9648     NaN       4   3900000.0       100  Free     0       Everyone
# 9649     4.1      80  13000000.0      1000  Free     0       Everyone
# 9650     NaN      20   2700000.0     10000  Free     0       Everyone
# 9651     4.0     785  31000000.0     50000  Free     0           Teen
# 9652     4.2    5775   4900000.0    500000  Free     0       Everyone
# 9653     NaN       2   6800000.0       100  Free     0       Everyone
# 9654     4.0     885   8000000.0    100000  Free     0       Everyone
# 9655     NaN      96   1500000.0     10000  Free     0       Everyone
# 9656     3.3      52   3600000.0      5000  Free     0           Teen
# 9657     5.0      22   8600000.0      1000  Free     0           Teen
# 9658     NaN       6   2500000.0        50  Free     0       Everyone
# 9659     NaN       0   3100000.0        10  Free     0       Everyone
# 9660     NaN       1   2900000.0       100  Free     0       Everyone
# 9661     NaN      67  82000000.0     10000  Free     0       Everyone
# 9662     NaN       7   7700000.0       100  Free     0           Teen
# 9663     4.0   88486         NaN   5000000  Free     0     Mature 17+
# 9664     4.2     117  13000000.0      5000  Free     0       Everyone
# 9665     3.4     291  13000000.0     10000  Free     0       Everyone
# 9666     4.6     603   7400000.0     10000  Free     0       Everyone
# 9667     3.8     881   2300000.0    100000  Free     0       Everyone
# 9668     NaN      38   9800000.0      5000  Free     0       Everyone
# 9669     3.8    1195    582000.0    100000  Free     0       Everyone
# 9670     4.8      44    619000.0      1000  Free     0       Everyone
# 9671     4.0       7   2600000.0       500  Free     0       Everyone
# 9672     NaN       0   9600000.0        10  Free     0       Everyone
# 9673     4.5      38  53000000.0      5000  Free     0       Everyone
# 9674     5.0       4   3600000.0       100  Free     0       Everyone
# 9675     NaN       3   9500000.0      1000  Free     0       Everyone
# 9676     4.5     114         NaN      1000  Free     0     Mature 17+
# 9677     4.5  398307  19000000.0  10000000  Free     0       Everyone
#
#                                Genres        Last Updated Current Ver  \
# 0                        Art & Design     January 7, 2018       1.0.0
# 1           Art & Design;Pretend Play    January 15, 2018       2.0.0
# 2                        Art & Design      August 1, 2018       1.2.4
# 3                        Art & Design        June 8, 2018         NaN
# 4             Art & Design;Creativity       June 20, 2018         1.1
# 5                        Art & Design      March 26, 2017         1.0
# 6                        Art & Design      April 26, 2018         1.1
# 7                        Art & Design       June 14, 2018    6.1.61.1
# 8                        Art & Design  September 20, 2017       2.9.2
# 9             Art & Design;Creativity        July 3, 2018         2.8
# 10                       Art & Design    October 27, 2017       1.0.4
# 11                       Art & Design       July 31, 2018      1.0.15
# 12                       Art & Design       April 2, 2018         3.8
# 13                       Art & Design       June 26, 2018       1.0.4
# 14                       Art & Design      August 3, 2018       1.2.3
# 15                       Art & Design        June 6, 2018         NaN
# 16                       Art & Design       July 31, 2018         3.1
# 17                       Art & Design    November 7, 2017         1.0
# 18                       Art & Design      August 3, 2018       2.2.5
# 19                       Art & Design       July 30, 2018       5.5.4
# 20                       Art & Design      April 20, 2018         4.0
# 21                       Art & Design      March 20, 2018         1.1
# 22                       Art & Design       July 12, 2018     2.2.6.2
# 23    Art & Design;Action & Adventure       March 7, 2018       1.0.0
# 24                       Art & Design        July 7, 2018       1.1.3
# 25                       Art & Design      April 25, 2018         1.5
# 26            Art & Design;Creativity    October 11, 2017       1.0.8
# 27                       Art & Design      March 21, 2018        1.03
# 28                       Art & Design       July 12, 2018         6.0
# 29                       Art & Design     August 22, 2017         1.0
# ...                               ...                 ...         ...
# 9648                  Auto & Vehicles       July 24, 2018       1.3.6
# 9649                        Education       June 13, 2018      2.0.20
# 9650                         Business       July 17, 2018      2.1.10
# 9651                    Entertainment        June 3, 2015       1.3.1
# 9652                Books & Reference       July 19, 2018     7.0.4.6
# 9653                         Business      August 6, 2018       2.1.8
# 9654                            Tools    October 30, 2015  1.0.612928
# 9655                          Finance        May 19, 2016         2.3
# 9656                Books & Reference      August 5, 2017       0.3.4
# 9657                        Education       June 27, 2018       3.8.0
# 9658                    Entertainment        May 29, 2018         1.0
# 9659                     Productivity    December 1, 2017           1
# 9660          Video Players & Editors      April 22, 2018         1.0
# 9661                          Medical       July 31, 2018       2.2.2
# 9662                           Social    February 2, 2018         1.0
# 9663                           Social      March 23, 2018         NaN
# 9664                        Education       June 13, 2018      2.0.20
# 9665                           Comics        May 15, 2017       2.0.1
# 9666                Books & Reference       June 19, 2016        2.96
# 9667                 News & Magazines    January 20, 2014         1.5
# 9668                Maps & Navigation       June 13, 2018   2.0.148.0
# 9669                          Weather   February 16, 2014         6.0
# 9670                Books & Reference      March 23, 2014         0.8
# 9671                        Education       June 18, 2017       1.0.0
# 9672                         Business  September 29, 2016       1.1.5
# 9673                        Education       July 25, 2017        1.48
# 9674                        Education        July 6, 2018         1.0
# 9675                          Medical    January 20, 2017         1.0
# 9676                Books & Reference    January 19, 2015         NaN
# 9677                        Lifestyle       July 25, 2018         NaN
#
#      Android Ver
# 0          4.0.3
# 1          4.0.3
# 2          4.0.3
# 3            4.2
# 4            4.4
# 5            2.3
# 6          4.0.3
# 7            4.2
# 8            3.0
# 9          4.0.3
# 10           4.1
# 11           4.0
# 12           4.1
# 13           4.4
# 14           2.3
# 15           4.2
# 16           4.1
# 17           2.3
# 18         4.0.3
# 19           4.1
# 20           4.1
# 21         4.0.3
# 22         4.0.3
# 23           4.1
# 24           4.1
# 25           3.0
# 26         4.0.3
# 27         4.0.3
# 28           2.3
# 29           2.3
# ...          ...
# 9648         4.4
# 9649       4.0.3
# 9650         4.1
# 9651         3.0
# 9652         4.2
# 9653         4.1
# 9654         5.0
# 9655         2.2
# 9656         4.1
# 9657         4.1
# 9658       4.0.3
# 9659         4.4
# 9660       4.0.3
# 9661         4.4
# 9662         4.0
# 9663         NaN
# 9664       4.0.3
# 9665         4.0
# 9666         4.1
# 9667         1.6
# 9668         4.0
# 9669         2.1
# 9670         2.2
# 9671         4.1
# 9672         4.0
# 9673         4.1
# 9674         4.1
# 9675         2.2
# 9676         NaN
# 9677         NaN
#
# [9678 rows x 13 columns]

# %% [markdown]
# # 6. For each category, compute the number of apps

# %%
# Count the Apps for each category
df_store.groupby(['Category']).size().reset_index(name='counts')
# Out:
#                Category  counts
# 0        ART_AND_DESIGN      64
# 1     AUTO_AND_VEHICLES      85
# 2                BEAUTY      53
# 3   BOOKS_AND_REFERENCE     222
# 4              BUSINESS     420
# 5                COMICS      56
# 6         COMMUNICATION     316
# 7                DATING     171
# 8             EDUCATION     119
# 9         ENTERTAINMENT     102
# 10               EVENTS      64
# 11               FAMILY    1836
# 12              FINANCE     345
# 13       FOOD_AND_DRINK     112
# 14                 GAME     963
# 15   HEALTH_AND_FITNESS     288
# 16       HOUSE_AND_HOME      74
# 17   LIBRARIES_AND_DEMO      84
# 18            LIFESTYLE     369
# 19  MAPS_AND_NAVIGATION     131
# 20              MEDICAL     400
# 21   NEWS_AND_MAGAZINES     254
# 22            PARENTING      60
# 23      PERSONALIZATION     376
# 24          PHOTOGRAPHY     283
# 25         PRODUCTIVITY     374
# 26             SHOPPING     202
# 27               SOCIAL     239
# 28               SPORTS     325
# 29                TOOLS     830
# 30     TRAVEL_AND_LOCAL     219
# 31        VIDEO_PLAYERS     163
# 32              WEATHER      79

# %% [markdown]
# # 7. For each category, compute the average rating

# %%
# Average for category
df_store.groupby(df_store['Category']).mean()['Rating']
# Out:
# Category
# ART_AND_DESIGN         4.357377
# AUTO_AND_VEHICLES      4.190411
# BEAUTY                 4.278571
# BOOKS_AND_REFERENCE    4.344970
# BUSINESS               4.098479
# COMICS                 4.181481
# COMMUNICATION          4.121401
# DATING                 3.970149
# EDUCATION              4.364407
# ENTERTAINMENT          4.135294
# EVENTS                 4.435556
# FAMILY                 4.180335
# FINANCE                4.115563
# FOOD_AND_DRINK         4.172340
# GAME                   4.248362
# HEALTH_AND_FITNESS     4.243033
# HOUSE_AND_HOME         4.150000
# LIBRARIES_AND_DEMO     4.178125
# LIFESTYLE              4.093355
# MAPS_AND_NAVIGATION    4.036441
# MEDICAL                4.171088
# NEWS_AND_MAGAZINES     4.121569
# PARENTING              4.300000
# PERSONALIZATION        4.332215
# PHOTOGRAPHY            4.156981
# PRODUCTIVITY           4.183389
# SHOPPING               4.230000
# SOCIAL                 4.247291
# SPORTS                 4.216154
# TOOLS                  4.041193
# TRAVEL_AND_LOCAL       4.069519
# VIDEO_PLAYERS          4.044595
# WEATHER                4.243056
# Name: Rating, dtype: float64

# %% [markdown]
# # 8. Create two dataframes: one for the genres and one bridging apps and genres. So that, for instance, the app Pixel Draw - Number Art Coloring Book appears twice in the bridging table, once for Art & Design, once for Creativity

# %%
#8.1 create dataframe for genres
# Create a dataframe with splitted genres
d_genres=pd.DataFrame(df_store['Genres'])
d_genres=d_genres['Genres'].str.split(';', 1, expand=True)
d_genres.head()
# Out:
#               0             1
# 0  Art & Design          None
# 1  Art & Design  Pretend Play
# 2  Art & Design          None
# 3  Art & Design          None
# 4  Art & Design    Creativity

# %%
#create two dataframe for the corrisponding splitted genres column
d_genres0=pd.DataFrame(d_genres[0]) #column genres 1
d_genres1=pd.DataFrame(d_genres[1]) #column genres 2

#rename the column of the two dataframe with a unique name
d_genres1.columns=['Genre']
d_genres1=d_genres1.dropna() #remove NA value
d_genres0.columns=['Genre']

#Concatenate 
d_genre_conc=pd.concat([d_genres1, d_genres0], ignore_index=True, sort=False)
d_genre_conc= d_genre_conc.reset_index(drop=True)
d_genre_conc = d_genre_conc.groupby(d_genre_conc['Genre']).sum()
d_genre_conc
# Out:
# Empty DataFrame
# Columns: []
# Index: [Action, Action & Adventure, Adventure, Arcade, Art & Design, Auto & Vehicles, Beauty, Board, Books & Reference, Brain Games, Business, Card, Casino, Casual, Comics, Communication, Creativity, Dating, Education, Educational, Entertainment, Events, Finance, Food & Drink, Health & Fitness, House & Home, Libraries & Demo, Lifestyle, Maps & Navigation, Medical, Music, Music & Audio, Music & Video, News & Magazines, Parenting, Personalization, Photography, Pretend Play, Productivity, Puzzle, Racing, Role Playing, Shopping, Simulation, Social, Sports, Strategy, Tools, Travel & Local, Trivia, Video Players & Editors, Weather, Word]

# %%
#8.2 create bridge dataframe
#create two dataframe with the splitted column "genres"
d_bridge=pd.DataFrame(df_store[['App','Genres']])
d_bridge[['Genre1','Genre2']]=d_bridge['Genres'].str.split(';', 1, expand=True)
d_bridge=pd.DataFrame(d_bridge[['App','Genre1','Genre2']])
d_bridge.head()
# Out:
#                                                  App        Genre1  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design
# 1                                Coloring book moana  Art & Design
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design
# 3                              Sketch - Draw & Paint  Art & Design
# 4              Pixel Draw - Number Art Coloring Book  Art & Design
#
#          Genre2
# 0          None
# 1  Pretend Play
# 2          None
# 3          None
# 4    Creativity

# %%
# create a unique dataframe concatenating the 1st dataframe and the 2nd dataframe in a sequential way
i=len(d_bridge)
i=i+1
j=0
#add a new row with the value of the second dataframe
for n in d_bridge['App']:
    d_bridge.loc[i]=[d_bridge['App'][j],d_bridge['Genre2'][j],d_bridge['Genre2'][j]]
    i=i+1
    j=j+1
d_bridge=pd.DataFrame(d_bridge[['App','Genre1']])
d_bridge=d_bridge.dropna()
d_bridge.columns=['App','Genre'] #rename columns
d_bridge= d_bridge.reset_index(drop=True)
d_bridge.head()
# Out:
#                                                  App         Genre
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design
# 1                                Coloring book moana  Art & Design
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design
# 3                              Sketch - Draw & Paint  Art & Design
# 4              Pixel Draw - Number Art Coloring Book  Art & Design

# %%
#test with an App which has two genres
d_bridge.loc[d_bridge['App'] == 'Hair saloon - Spa salon']
# Out:
#                            App         Genre
# 9350   Hair saloon - Spa salon        Casual
# 10071  Hair saloon - Spa salon  Pretend Play

# %% [markdown]
# # 9. For each genre, create a new column of the original dataframe. The new columns must have boolean values (True if the app has a given genre)

# %%
df_store["Check_Genres"] = df_store["Genres"].notnull()
df_store.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size  Installs  Type Price Content Rating  \
# 0     159  19000000.0     10000  Free     0       Everyone
# 1     967  14000000.0    500000  Free     0       Everyone
# 2   87510   8700000.0   5000000  Free     0       Everyone
# 3  215644  25000000.0  50000000  Free     0           Teen
# 4     967   2800000.0    100000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver Android Ver  \
# 0               Art & Design   January 7, 2018       1.0.0       4.0.3
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0       4.0.3
# 2               Art & Design    August 1, 2018       1.2.4       4.0.3
# 3               Art & Design      June 8, 2018         NaN         4.2
# 4    Art & Design;Creativity     June 20, 2018         1.1         4.4
#
#    Check_Genres
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True

# %% [markdown]
# # 10. For each genre, compute the average rating. What is the genre with highest average?

# %%
high_rate=df_store['Rating'].groupby(df_store['Genres']).mean().nlargest(20)
high_rate=high_rate.dropna()
high_rate
# Out:
# Genres
# Board;Pretend Play                 4.800000
# Comics;Creativity                  4.800000
# Health & Fitness;Education         4.700000
# Adventure;Brain Games              4.600000
# Puzzle;Education                   4.600000
# Strategy;Action & Adventure        4.600000
# Entertainment;Creativity           4.533333
# Music;Music & Video                4.533333
# Arcade;Pretend Play                4.500000
# Racing;Pretend Play                4.500000
# Strategy;Education                 4.500000
# Tools;Education                    4.500000
# Casual;Brain Games                 4.475000
# Events                             4.435556
# Education;Brain Games              4.433333
# Role Playing;Action & Adventure    4.425000
# Card;Brain Games                   4.400000
# Entertainment;Education            4.400000
# Puzzle;Creativity                  4.400000
# Strategy;Creativity                4.400000
# Name: Rating, dtype: float64

# %% [markdown]
# # 11. For each app, compute the approximate income, obtain as a product of number of installs and price.

# %%
#apply the function which mantains only numbers and point character
df_store["Price"]=df_store.apply(lambda x:convert_number(x["Price"]),axis=1)

# %%
# Calculate the approximate income as numbers of installation*price
i=0
df_store["Income"]=None
for n in df_store['App']:
    df_store["Income"][i] =int(df_store["Installs"][i])*float(df_store['Price'][i])
    i=i+1
    
df_store["Income"]=df_store["Income"].astype(float)
df_store.sort_values(by=['Income'],ascending=False)
# Out:
#                                                     App             Category  \
# 1748                                          Minecraft               FAMILY
# 4408                                          I am rich            LIFESTYLE
# 4412                                  I Am Rich Premium              FINANCE
# 3219                                      Hitman Sniper                 GAME
# 6385                      Grand Theft Auto: San Andreas                 GAME
# 2267                                Facetune - For Free          PHOTOGRAPHY
# 4619                            Sleep as Android Unlock            LIFESTYLE
# 7704                                DraStic DS Emulator                 GAME
# 3480                           I'm Rich - Trump Edition            LIFESTYLE
# 4410                                     I am Rich Plus               FAMILY
# 3476                                         💎 I'm rich            LIFESTYLE
# 4422                                          I Am Rich               FAMILY
# 4411                                      I am rich VIP            LIFESTYLE
# 3285                                       Weather Live              WEATHER
# 8804                                             Tasker                TOOLS
# 6323                                            Threema        COMMUNICATION
# 4662                            Five Nights at Freddy's                 GAME
# 7760                                        Bloons TD 5               FAMILY
# 1749                         Card Wars - Adventure Time               FAMILY
# 1758   Human Anatomy Atlas 2018: Complete 3D Human Body              MEDICAL
# 8051                              NBA JAM by EA SPORTS™               FAMILY
# 2682                              Beautiful Widgets Pro      PERSONALIZATION
# 4415                                 I am rich(premium)              FINANCE
# 4418                                      I Am Rich Pro               FAMILY
# 4425                                          I am Rich              FINANCE
# 690                                     Toca Life: City            EDUCATION
# 8556                                  Where's My Water?               FAMILY
# 4538                                         True Skate               SPORTS
# 2383                            Golfshot Plus: Golf GPS               SPORTS
# 7633                                    DRAGON QUEST VI               FAMILY
# ...                                                 ...                  ...
# 3258                     EBookDroid - PDF & DJVU Reader         PRODUCTIVITY
# 3259                                              E-NUM              FINANCE
# 3260                                 Aldiko Book Reader  BOOKS_AND_REFERENCE
# 3262                      Video Downloader for Facebook                TOOLS
# 3252                         World History Quick e-Book               FAMILY
# 3264                             Offroad Pickup Truck F               FAMILY
# 3265                                     F-Stop Gallery          PHOTOGRAPHY
# 3266                                  Talking Tom Cat 2               FAMILY
# 3267                                 FlashLight F.Light                TOOLS
# 3268                                     F-Secure SENSE                TOOLS
# 3269                          Super Car F. Mod for MCPE                 GAME
# 3253                            Greeting Cards & Wishes               SOCIAL
# 3251                       Lookout Security & Antivirus                TOOLS
# 3235                           Z Ringtones PREMIUM 2018      PERSONALIZATION
# 3242  Car Parking Game 3D - Real City Driving Challenge               FAMILY
# 3236                                          Smash Hit                 GAME
# 3237                                        Bad Piggies               FAMILY
# 3238                                         Temple Run                 GAME
# 3239                                Broken Screen Prank               FAMILY
# 3240           Screen Lock - with Fingerprint Simulator                TOOLS
# 3241                              Tuner - gStrings Free                TOOLS
# 3243                                                 E!               FAMILY
# 3250                        Mobile Security & Antivirus         PRODUCTIVITY
# 3244                                            E! News   NEWS_AND_MAGAZINES
# 3245                          Chuck E.'s Skate Universe               FAMILY
# 3246  Eventbrite - Discover popular events & nearby fun               FAMILY
# 3247                                           Eternium               FAMILY
# 3248                               E-cigarette for free               FAMILY
# 3249                     Moto LED for Moto X & E [Root]            LIFESTYLE
# 9677      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating  Reviews        Size   Installs  Type   Price Content Rating  \
# 1748     4.5  2376564         NaN   10000000  Paid    6.99   Everyone 10+
# 4408     3.8     3547   1800000.0     100000  Paid  399.99       Everyone
# 4412     4.1     1867   4700000.0      50000  Paid  399.99       Everyone
# 3219     4.6   408292  29000000.0   10000000  Paid    0.99     Mature 17+
# 6385     4.4   348962  26000000.0    1000000  Paid    6.99     Mature 17+
# 2267     4.4    49553  48000000.0    1000000  Paid    5.99       Everyone
# 4619     4.5    23966    872000.0    1000000  Paid    5.99       Everyone
# 7704     4.6    87766  12000000.0    1000000  Paid    4.99       Everyone
# 3480     3.6      275   7300000.0      10000  Paid  400.00       Everyone
# 4410     4.0      856   8700000.0      10000  Paid  399.99       Everyone
# 3476     3.8      718  26000000.0      10000  Paid  399.99       Everyone
# 4422     3.6      217   4900000.0      10000  Paid  389.99       Everyone
# 4411     3.8      411   2600000.0      10000  Paid  299.99       Everyone
# 3285     4.5    76593         NaN     500000  Paid    5.99       Everyone
# 8804     4.6    43045         NaN    1000000  Paid    2.99       Everyone
# 6323     4.5    51110         NaN    1000000  Paid    2.99       Everyone
# 4662     4.6   100805  50000000.0    1000000  Paid    2.99           Teen
# 7760     4.6   190086  94000000.0    1000000  Paid    2.99       Everyone
# 1749     4.3   129603  23000000.0    1000000  Paid    2.99   Everyone 10+
# 1758     4.5     2921  25000000.0     100000  Paid   24.99       Everyone
# 8051     4.3    56444  43000000.0     500000  Paid    4.99       Everyone
# 2682     4.2    97890  14000000.0    1000000  Paid    2.49       Everyone
# 4415     3.5      472    965000.0       5000  Paid  399.99       Everyone
# 4418     4.4      201   2700000.0       5000  Paid  399.99       Everyone
# 4425     4.3      180   3800000.0       5000  Paid  399.99       Everyone
# 690      4.7    31085  24000000.0     500000  Paid    3.99       Everyone
# 8556     4.7   188740  69000000.0    1000000  Paid    1.99       Everyone
# 4538     4.4   129409  73000000.0    1000000  Paid    1.99       Everyone
# 2383     4.1     3387  25000000.0      50000  Paid   29.99       Everyone
# 7633     4.4     3358  17000000.0     100000  Paid   14.99       Everyone
# ...      ...      ...         ...        ...   ...     ...            ...
# 3258     4.5    75951         NaN    5000000  Free       0       Everyone
# 3259     4.0    10374         NaN     500000  Free       0       Everyone
# 3260     4.2   210534  22000000.0   10000000  Free       0       Everyone
# 3262     4.6   894435   3100000.0   50000000  Free       0           Teen
# 3252     4.4     1657   4900000.0     100000  Free       0       Everyone
# 3264     4.3     4551  79000000.0     500000  Free       0       Everyone
# 3265     4.2    12726  15000000.0    1000000  Free       0       Everyone
# 3266     4.3  3213548  55000000.0  100000000  Free       0   Everyone 10+
# 3267     4.3     3943  11000000.0     100000  Free       0       Everyone
# 3268     4.6       57  13000000.0       5000  Free       0       Everyone
# 3269     3.6      214   4900000.0      50000  Free       0       Everyone
# 3253     4.5    17350  12000000.0     500000  Free       0       Everyone
# 3251     4.4   951413  13000000.0  100000000  Free       0       Everyone
# 3235     4.5    10158   3600000.0     500000  Free       0       Everyone
# 3242     4.4   187892  40000000.0    5000000  Free       0       Everyone
# 3236     4.5  4147718  79000000.0  100000000  Free       0       Everyone
# 3237     4.3  1168959  66000000.0   50000000  Free       0       Everyone
# 3238     4.3  4000433  42000000.0  100000000  Free       0       Everyone
# 3239     3.3    23682   9800000.0    1000000  Free       0           Teen
# 3240     3.7   338449   2800000.0   10000000  Free       0       Everyone
# 3241     4.5   214265         NaN   10000000  Free       0       Everyone
# 3243     3.1      740  20000000.0     100000  Free       0           Teen
# 3250     4.7   564759         NaN   10000000  Free       0       Everyone
# 3244     4.0    15443  25000000.0    1000000  Free       0           Teen
# 3245     3.9    94910  44000000.0   10000000  Free       0       Everyone
# 3246     4.4    63773   8800000.0    5000000  Free       0       Everyone
# 3247     4.8  1506783  89000000.0   10000000  Free       0           Teen
# 3248     3.6     1354   4800000.0     500000  Free       0     Mature 17+
# 3249     3.4     4082    318000.0     500000  Free       0       Everyone
# 9677     4.5   398307  19000000.0   10000000  Free       0       Everyone
#
#                          Genres       Last Updated    Current Ver Android Ver  \
# 1748  Arcade;Action & Adventure      July 24, 2018        1.5.2.1         NaN
# 4408                  Lifestyle   January 12, 2018            2.0       4.0.3
# 4412                    Finance  November 12, 2017            1.6         4.0
# 3219                     Action      July 12, 2018     1.7.110758         4.1
# 6385                     Action     March 21, 2015           1.08         3.0
# 2267                Photography      July 25, 2018          1.3.1         4.1
# 4619                  Lifestyle      June 27, 2018       20180608         4.0
# 7704                     Action      July 19, 2016        2.5.0.3         2.3
# 3480                  Lifestyle        May 3, 2018          1.0.1         4.1
# 4410              Entertainment       May 19, 2018            3.0         4.4
# 3476                  Lifestyle     March 11, 2018          1.0.0         4.4
# 4422              Entertainment      June 22, 2018            1.5         4.2
# 4411                  Lifestyle      July 21, 2018          1.1.1         4.3
# 3285                    Weather  November 21, 2017            NaN         NaN
# 8804                      Tools      June 25, 2018            NaN         NaN
# 6323              Communication     August 3, 2018            NaN         NaN
# 4662                     Action   December 2, 2014           1.85         2.3
# 7760                   Strategy      July 13, 2018           3.16       2.3.3
# 1749    Card;Action & Adventure  February 11, 2016         1.11.0       2.3.3
# 1758                    Medical       May 25, 2018      2018.5.47         5.0
# 8051  Sports;Action & Adventure   February 8, 2017       04.00.40         2.3
# 2682            Personalization    August 24, 2016          5.7.8         2.3
# 4415                    Finance        May 1, 2017            3.4         4.4
# 4418              Entertainment       May 30, 2017           1.54         1.6
# 4425                    Finance     March 22, 2018            1.0         4.2
# 690      Education;Pretend Play       July 6, 2018            1.5         4.4
# 8556         Puzzle;Brain Games       July 5, 2018         1.16.0         4.2
# 4538                     Sports     August 4, 2018          1.5.1       4.0.3
# 2383                     Sports      July 11, 2018         4.18.0         4.1
# 7633               Role Playing     August 1, 2018          1.0.4         2.3
# ...                         ...                ...            ...         ...
# 3258               Productivity       July 8, 2018            NaN         NaN
# 3259                    Finance   October 24, 2016            NaN         NaN
# 3260          Books & Reference      June 13, 2018         3.0.58         4.0
# 3262                      Tools       July 1, 2018          2.2.8         4.0
# 3252        Education;Education      July 17, 2018           1.35         4.1
# 3264                 Simulation  December 26, 2017            1.0         2.3
# 3265                Photography      July 21, 2018         4.9.18         4.1
# 3266              Entertainment      July 25, 2018       5.3.5.16         4.1
# 3267                      Tools       May 23, 2018          1.4.2         5.0
# 3268                      Tools       July 4, 2018        1.0.988         5.0
# 3269                  Adventure      July 19, 2018          3.0.1         4.2
# 3253                     Social      July 18, 2018          1.078         NaN
# 3251                      Tools      July 31, 2018  10.23.2964159         4.4
# 3235            Personalization      March 1, 2018            1.5       4.0.3
# 3242                 Simulation       May 10, 2018          1.2.0         4.0
# 3236                     Arcade  November 26, 2015          1.4.0         2.3
# 3237                     Puzzle        May 3, 2017          2.3.3         4.1
# 3238                     Arcade     August 2, 2018          1.9.1         4.0
# 3239                     Casual      June 14, 2018            6.2         4.0
# 3240                      Tools      June 19, 2018            8.6       2.3.3
# 3241                      Tools       June 4, 2018            NaN         NaN
# 3243              Entertainment       May 24, 2018       3.3.1.41         4.4
# 3250               Productivity      July 27, 2018            NaN         NaN
# 3244           News & Magazines      June 19, 2018        4.2.133         4.4
# 3245  Action;Action & Adventure   January 10, 2017           1.12         4.3
# 3246              Entertainment      July 30, 2018          5.7.2         5.0
# 3247               Role Playing      July 18, 2018        1.2.115         4.0
# 3248              Entertainment   October 23, 2017            1.0         2.3
# 3249                  Lifestyle   October 16, 2014            1.0         4.2
# 9677                  Lifestyle      July 25, 2018            NaN         NaN
#
#       Check_Genres      Income
# 1748          True  69900000.0
# 4408          True  39999000.0
# 4412          True  19999500.0
# 3219          True   9900000.0
# 6385          True   6990000.0
# 2267          True   5990000.0
# 4619          True   5990000.0
# 7704          True   4990000.0
# 3480          True   4000000.0
# 4410          True   3999900.0
# 3476          True   3999900.0
# 4422          True   3899900.0
# 4411          True   2999900.0
# 3285          True   2995000.0
# 8804          True   2990000.0
# 6323          True   2990000.0
# 4662          True   2990000.0
# 7760          True   2990000.0
# 1749          True   2990000.0
# 1758          True   2499000.0
# 8051          True   2495000.0
# 2682          True   2490000.0
# 4415          True   1999950.0
# 4418          True   1999950.0
# 4425          True   1999950.0
# 690           True   1995000.0
# 8556          True   1990000.0
# 4538          True   1990000.0
# 2383          True   1499500.0
# 7633          True   1499000.0
# ...            ...         ...
# 3258          True         0.0
# 3259          True         0.0
# 3260          True         0.0
# 3262          True         0.0
# 3252          True         0.0
# 3264          True         0.0
# 3265          True         0.0
# 3266          True         0.0
# 3267          True         0.0
# 3268          True         0.0
# 3269          True         0.0
# 3253          True         0.0
# 3251          True         0.0
# 3235          True         0.0
# 3242          True         0.0
# 3236          True         0.0
# 3237          True         0.0
# 3238          True         0.0
# 3239          True         0.0
# 3240          True         0.0
# 3241          True         0.0
# 3243          True         0.0
# 3250          True         0.0
# 3244          True         0.0
# 3245          True         0.0
# 3246          True         0.0
# 3247          True         0.0
# 3248          True         0.0
# 3249          True         0.0
# 9677          True         0.0
#
# [9678 rows x 15 columns]

# %% [markdown]
# # 12. For each app, compute its minimum and maximum Sentiment_polarity

# %%
#compute minimum, compute maximum
max_test=df_reviews['Sentiment_Polarity'].groupby(df_reviews['App']).max().reset_index(name='max_sent')
min_test=df_reviews['Sentiment_Polarity'].groupby(df_reviews['App']).min().reset_index(name='min_sent')
#merge togheter the two results
result = pd.merge(min_test, max_test, left_on = 'App', right_on = 'App', how = 'inner')
result
# Out:
#                                                     App  min_sent  max_sent
# 0                                 10 Best Foods for You -0.800000  1.000000
# 1                      104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室 -0.112500  0.910000
# 2                                                  11st -1.000000  1.000000
# 3                            1800 Contacts - Lens Store -0.300000  0.838542
# 4                       1LINE – One Line with One Touch -0.825000  1.000000
# 5      2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif -0.800000  1.000000
# 6                          21-Day Meditation Experience -0.265625  0.587500
# 7                   2Date Dating App, Love and matching -0.645833  1.000000
# 8                           2GIS: directory & navigator -0.375000  1.000000
# 9                                             2RedBeans -0.800000  1.000000
# 10                        2ndLine - Second Phone Number -0.781250  1.000000
# 11           30 Day Fitness Challenge - Workout at Home -0.500000  0.900000
# 12                              365Scores - Live Scores  0.000000  1.000000
# 13                   3D Blue Glass Water Keyboard Theme       NaN       NaN
# 14      3D Color Pixel by Number - Sandbox Art Coloring       NaN       NaN
# 15                           3D Live Neon Weed Launcher  0.136364  1.000000
# 16                                           4 in a Row -0.800000  1.000000
# 17               4K Wallpapers and Ultra HD Backgrounds -0.700000  0.750000
# 18    591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價... -0.300000  0.700000
# 19                                           591房屋交易-香港 -0.077083  0.700000
# 20                        7 Cups: Anxiety & Stress Chat -0.172222  0.812500
# 21                         7 Day Food Journal Challenge  0.070000  0.343333
# 22                                     7 Minute Workout -0.291667  1.000000
# 23                       7 Weeks - Habit & Goal Tracker -0.132576  0.471212
# 24                                          8 Ball Pool -1.000000  0.650000
# 25                               850 Sports News Digest -0.500000  1.000000
# 26                         8fit Workouts & Meal Planner -0.700000  0.800000
# 27                      95Live -SG#1 Live Streaming App -0.937500  1.000000
# 28                             A Call From Santa Claus! -1.000000  0.700000
# 29                              A Manual of Acupuncture       NaN       NaN
# ...                                                 ...       ...       ...
# 1044      Hole19: Golf GPS App, Rangefinder & Scorecard  0.000000  1.000000
# 1045  Home Decor Showpiece Art making: Medium Diffic... -1.000000  0.780000
# 1046                          Home Scouting® MLS Mobile -0.800000  1.000000
# 1047  Home Security Camera WardenCam - reuse old phones -0.800000  1.000000
# 1048                     Home Street – Home Design Game -0.750000  0.600000
# 1049                        Home Workout - No Equipment -0.016667  1.000000
# 1050                Home Workout for Men - Bodybuilding  0.000000  1.000000
# 1051  Home workouts - fat burning, abs, legs, arms,c...  0.050000  0.800000
# 1052                          HomeAway Vacation Rentals       NaN       NaN
# 1053                                           HomeWork  1.000000  1.000000
# 1054                         Homes.com 🏠 For Sale, Rent -0.600000  1.000000
# 1055                                         Homescapes -0.197917  0.503571
# 1056                     Homesnap Real Estate & Rentals -0.600000  1.000000
# 1057      Homestyler Interior Design & Decorating Ideas -0.400000  0.988281
# 1058                                   Homework Planner -0.208333  0.718750
# 1059                                  Honkai Impact 3rd -0.237500  0.775000
# 1060                      Hopper - Watch & Book Flights -0.937500  0.761905
# 1061  Horoscopes – Daily Zodiac Horoscope and Astrology -0.040476  1.000000
# 1062                              Horses Live Wallpaper -0.656250  1.000000
# 1063     Hostelworld: Hostels & Cheap Hotels Travel App -1.000000  1.000000
# 1064                               Hot Wheels: Race Off -0.625000  0.391667
# 1065                Hot or Not - Find someone right now       NaN       NaN
# 1066   HotelTonight: Book amazing deals at great hotels -1.000000  1.000000
# 1067                      Hotels Combined - Cheap deals -0.700000  1.000000
# 1068  Hotels.com: Book Hotel Rooms & Find Vacation D... -0.988281  0.700000
# 1069     Hotspot Shield Free VPN Proxy & Wi-Fi Security -0.700000  1.000000
# 1070                                            Hotstar -0.555556  1.000000
# 1071                     Hotwire Hotel & Car Rental App -0.875000  0.800000
# 1072                     Housing-Real Estate & Property -0.528571  0.800000
# 1073                        Houzz Interior Design Ideas       NaN       NaN
#
# [1074 rows x 3 columns]
